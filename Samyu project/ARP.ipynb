# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# read dataset
ds = pd.read_excel('online_retail.xlsx')

# %%
data = ds.copy()

# %%
data.shape
#(525461, 8)

data.columns
len(data['Description'].unique().tolist())
# 4682
# Out:
# 4682

# %%
# which item is bought more frequently
plt.figure(figsize=(20, 5))

plt.xticks(rotation=90)


plt.bar(data['Country'].unique(), data['Country'].value_counts(), log=True, alpha=0.4, )
plt.plot(data['Country'].unique(), data['Country'].value_counts(), 'r--')

# %%
data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
# Which user bought more products
plt.figure(figsize=(80, 5))

data['Customer ID'] = [str(i) for i in data['Customer ID']]
plt.bar(data['Customer ID'].unique(), data['Customer ID'].value_counts(), log=True, alpha=0.4)
for i in plt.gca().xaxis.get_ticklabels():
    i.set_rotation(90)

data['Customer ID'] = [float(i) for i in data['Customer ID']]

# %%
# Identify possibilities

# %%
# What ML process can be used for which possibility

# %% [markdown]
# ## Data Set Information:
# * This Online Retail II data set contains all the transactions occurring for a UK-based and registered, non-store online retail between 01/12/2009 and 09/12/2011.
# * The company mainly sells unique all-occasion gift-ware.
# * Many customers of the company are wholesalers.
